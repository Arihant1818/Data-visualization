# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
df1 = pd.read_csv('/gdrive/MyDrive/Files/A.csv')
pd.read_csv('/gdrive/MyDrive/Files/A.csv', 
            sep = r',', 
            skipinitialspace = True)

df1.iloc[:,6:]=df1.iloc[:,6:].apply(le.fit_transform)
df1.head()
# Out:
#            Timestamp 1. Your Name  (आपका नाम)  ... Q20 Q21
# 0  6/8/2021 22:54:10             lakeraj jain  ...  12   2
# 1   6/9/2021 0:32:53             Vinit Pandya  ...   0   0
# 2   6/9/2021 0:39:11           Sanskar sharma  ...   0   2
# 3   6/9/2021 1:19:39                    Disha  ...   5   1
# 4   6/9/2021 1:29:34             Deval Pandya  ...  12   0
#
# [5 rows x 27 columns]

# %%
df2 = pd.read_csv('/gdrive/MyDrive/Files/B.csv')
pd.read_csv('/gdrive/MyDrive/Files/B.csv', 
            sep = r',', 
            skipinitialspace = True)
df2.iloc[:,6:]=df2.iloc[:,6:].apply(le.fit_transform)
df2.head()
# Out:
#            Timestamp 1. Your Name  (optional) (आपका नाम)  ... Q20 Q21
# 0  6/9/2021 16:38:32                         Surbhi jain  ...  12   0
# 1  6/9/2021 16:40:40              Bharat Singh Shekhawat  ...   4   2
# 2  6/9/2021 16:40:40                                 NaN  ...   4   2
# 3  6/9/2021 16:46:56                       Piyush Dhuwan  ...   4   2
# 4  6/9/2021 16:50:04                         Saijal jain  ...   2   0
#
# [5 rows x 27 columns]

# %%
df3 = pd.read_csv('/gdrive/MyDrive/Files/C.csv')
pd.read_csv('/gdrive/MyDrive/Files/C.csv', 
            sep = r',', 
            skipinitialspace = True)
df3.iloc[:,6:]=df3.iloc[:,6:].apply(le.fit_transform)
df3.head()
# Out:
#             Timestamp       You Name(optional)  ... Q20 Q21
# 0  6/10/2021 18:32:15           Madhuri Batchu  ...   3   2
# 1  6/10/2021 18:34:23               Jeevan Sai  ...   2   0
# 2  6/10/2021 18:51:49  Harshith Sai Tunuguntla  ...   4   2
# 3  6/10/2021 18:53:36                 Mohammad  ...   2   1
# 4  6/10/2021 18:56:06                 B.Sindhu  ...   0   1
#
# [5 rows x 27 columns]

# %%
df4 = pd.read_csv('/gdrive/MyDrive/Files/D.csv')
pd.read_csv('/gdrive/MyDrive/Files/D.csv',
            sep = r',' , 
            skipinitialspace = True)
df4.iloc[:,6:]=df4.iloc[:,6:].apply(le.fit_transform)
df4.head()
# Out:
#             Timestamp Your Name (optional)  ... Q20 Q21
# 0  6/10/2021 17:00:03          Ishwar Jain  ...   3   2
# 1  6/10/2021 17:13:21                  NaN  ...   2   0
# 2  6/10/2021 17:16:04          Anshul soni  ...   4   2
# 3  6/10/2021 17:16:36         Mamta Sharma  ...   2   1
# 4  6/10/2021 17:20:41   Dr. Manish Kaushik  ...   0   1
#
# [5 rows x 27 columns]

# %%
df5 = pd.read_csv('/gdrive/MyDrive/Files/E.csv')
pd.read_csv('/gdrive/MyDrive/Files/E.csv', 
            sep = r',', 
            skipinitialspace = True)
df5.iloc[:,6:]=df5.iloc[:,6:].apply(le.fit_transform)
df5.head()
# Out:
#   1. Your Name  (optional) (आपका नाम)  ... Q21
# 0                      Gayatri sharma  ...   2
# 1                        vijesh mehta  ...   2
# 2                                  RK  ...   0
# 3                            Vanshika  ...   0
# 4                         Tejash Jain  ...   0
#
# [5 rows x 26 columns]

# %%
df6 = pd.read_csv('/gdrive/MyDrive/Files/F.csv')
pd.read_csv('/gdrive/MyDrive/Files/F.csv', 
            sep = r',', 
            skipinitialspace = True)
df6.iloc[:,6:]=df6.iloc[:,6:].apply(le.fit_transform)
df6.head()
# Out:
#              Timestamp Your Name (optional) (आपका नाम)  ... Q20 Q21
# 0  08/06/2021 23:54:09                   Nirmal pandey  ...   7   0
# 1   09/06/2021 8:01:44                    S.D. Mathpal  ...   9   2
# 2   09/06/2021 8:24:34             divya arjun rautela  ...   0   1
# 3  09/06/2021 11:02:52                Deepanshu tiwari  ...   7   2
# 4  09/06/2021 12:36:36                             NaN  ...   0   2
#
# [5 rows x 27 columns]

# %%
df7 = pd.read_csv('/gdrive/MyDrive/Files/G.csv')
pd.read_csv('/gdrive/MyDrive/Files/G.csv', 
            sep = r',', 
            skipinitialspace = True)
df7.iloc[:,6:]=df7.iloc[:,6:].apply(le.fit_transform)
df7.head()
# Out:
#            Timestamp 1.\tYour Name (optional) (आपका नाम) –  ... Q20 Q21
# 0  6/9/2021 20:49:07                          Purvi Sharma  ...   3   0
# 1  6/9/2021 20:53:28                                Madhur  ...   0   1
# 2  6/9/2021 20:56:22                    Neha Roy Mukherjee  ...   0   2
# 3  6/9/2021 21:03:31                                   NaN  ...   0   0
# 4  6/9/2021 21:07:58                       Anita Mukherjee  ...   3   0
#
# [5 rows x 27 columns]

# %%
df8 = pd.read_csv('/gdrive/MyDrive/Files/H.csv')
pd.read_csv('/gdrive/MyDrive/Files/H.csv', 
            sep = r',', 
            skipinitialspace = True)
df8.iloc[:,6:]=df8.iloc[:,6:].apply(le.fit_transform)
df8.head()
# Out:
#                         Timestamp 1. Your Name (optional) (आपका नाम)  ... Q20 Q21
# 0  2021/06/08 6:36:43 PM GMT+5:30                  Prince Jaspariya   ...   3   0
# 1  2021/06/08 7:19:36 PM GMT+5:30                    Ashish Chatwani  ...   0   2
# 2  2021/06/08 7:50:10 PM GMT+5:30                       Vijay paudel  ...   2   2
# 3  2021/06/08 7:58:11 PM GMT+5:30                     Ratanlal Barod  ...   0   2
# 4  2021/06/08 8:56:53 PM GMT+5:30                      Deepak Bairwa  ...   0   2
#
# [5 rows x 27 columns]

# %%
df9 = pd.read_csv('/gdrive/MyDrive/Files/I.csv')
pd.read_csv('/gdrive/MyDrive/Files/I.csv', 
            sep = r',', 
            skipinitialspace = True)
df9.iloc[:,6:]=df9.iloc[:,6:].apply(le.fit_transform)
df9.head()
# Out:
#            Timestamp 1. Your Name  (optional) (आपका नाम)  ... Q20 Q21
# 0  6/9/2021 14:17:55              Yeekshu kumari chouhan  ...   3   1
# 1  6/9/2021 14:24:24                        Ajay kuldeep  ...  12   0
# 2  6/9/2021 14:27:23                        Darshan jain  ...   6   0
# 3  6/9/2021 14:30:39                         Riya sharma  ...   9   1
# 4  6/9/2021 14:32:41                     Anirudh Purohit  ...  11   1
#
# [5 rows x 27 columns]

# %%
df10 = pd.read_csv('/gdrive/MyDrive/Files/J - J.csv')
pd.read_csv('/gdrive/MyDrive/Files/J - J.csv', 
            sep = r',', 
            skipinitialspace = True)
df10.iloc[:,6:]=df10.iloc[:,6:].apply(le.fit_transform)
df10.head()
# Out:
#            Timestamp Your Name (optional)  ... Q20 Q21
# 0  6/9/2021 16:59:13           Shrihari P  ...   2   1
# 1  6/9/2021 17:05:57          Surendhar.A  ...   8   2
# 2  6/9/2021 17:09:15                  NaN  ...   4   2
# 3  6/9/2021 17:13:15                  NaN  ...   0   0
# 4  6/9/2021 17:14:15            Niveditha  ...   0   2
#
# [5 rows x 27 columns]

# %%
final = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])
final.replace(np.nan,'Not answered')
final.head()
# Out:
#            Timestamp  ... How do you identify yourself from following
# 0  6/8/2021 22:54:10  ...                                         NaN
# 1   6/9/2021 0:32:53  ...                                         NaN
# 2   6/9/2021 0:39:11  ...                                         NaN
# 3   6/9/2021 1:19:39  ...                                         NaN
# 4   6/9/2021 1:29:34  ...                                         NaN
#
# [5 rows x 56 columns]

# %%
final.drop(columns=['Timestamp'],axis = 1)
# Out:
#    1. Your Name  (आपका नाम)  ... How do you identify yourself from following
# 0              lakeraj jain  ...                                         NaN
# 1              Vinit Pandya  ...                                         NaN
# 2            Sanskar sharma  ...                                         NaN
# 3                     Disha  ...                                         NaN
# 4              Deval Pandya  ...                                         NaN
# ..                      ...  ...                                         ...
# 20                      NaN  ...                            A Normal Citizen
# 21                      NaN  ...                            A Normal Citizen
# 22                      NaN  ...                            A Normal Citizen
# 23                      NaN  ...                            A Normal Citizen
# 24                      NaN  ...                            A Normal Citizen
#
# [292 rows x 55 columns]

# %%
final.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
final.plot(x='Q1', y='Q2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-968120c158d1> in <module>()
# ----> 1 final.plot(x='Q1', y='Q2')
#
# NameError: name 'final' is not defined

# %%
final['Q1'].sum()
# Out:
# 9.83610279215722

# %%
final['Q1'].count()
# Out:
# 20

# %%
final['Q1'].mean()
# Out:
# 0.49180513960786093
